# %% [markdown]
# <a href="https://colab.research.google.com/github/Evraa/Graduation-Project-Separate-Modules/blob/main/models/new-used-code/text_personality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/amirmohammadkz/personality_detection.git
# Out:
# Cloning into 'personality_detection'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 41 (delta 19), reused 9 (delta 4), pack-reused 0
# Unpacking objects: 100% (41/41), done.

# %%
cd /content/personality_detection/
# Out:
# /content/personality_detection

# %%
# !wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# !unzip uncased_L-12_H-768_A-12
# Out:
# --2021-07-19 14:27:40--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.123.128, 142.250.98.128, 173.194.218.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.123.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 407727028 (389M) [application/zip]
# Saving to: ‘uncased_L-12_H-768_A-12.zip’
#
# uncased_L-12_H-768_ 100%[===================>] 388.84M   157MB/s    in 2.5s
#
# 2021-07-19 14:27:42 (157 MB/s) - ‘uncased_L-12_H-768_A-12.zip’ saved [407727028/407727028]
#
# Archive:  uncased_L-12_H-768_A-12.zip
#    creating: uncased_L-12_H-768_A-12/
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: uncased_L-12_H-768_A-12/vocab.txt
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.index
# ...

# %%
# !pip install tensorflow==1.13.0rc1
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 92.7MB 46kB/s
# ...
#      |████████████████████████████████| 368kB 28.0MB/s
# ...
#      |████████████████████████████████| 51kB 5.8MB/s
# ...
#      |████████████████████████████████| 3.1MB 33.0MB/s
# ...
# ERROR: kapre 0.3.5 has requirement tensorflow>=2.0.0, but you'll have tensorflow 1.13.0rc1 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# ...
#      |████████████████████████████████| 14.5MB 241kB/s
# ...
#      |████████████████████████████████| 307kB 39.0MB/s
# ...
#      |████████████████████████████████| 71kB 8.1MB/s
# ...

# %%
# !python "shrink_data.py"
# Out:
# 2467

# %%
# !pip install bert-serving-client
# !pip install -U bert-serving-server[http]
# !nohup bert-serving-start -model_dir=./uncased_L-12_H-768_A-12 -cpu > out.file 2>&1 &
# Out:
# ...
# Requirement already up-to-date: bert-serving-server[http] in /usr/local/lib/python3.7/dist-packages (1.10.0)
# ...
#      |████████████████████████████████| 358kB 3.9MB/s
# ...

# %%
from bert_serving.client import BertClient
bc = BertClient()
print (bc.encode(['First do it', 'then do it right', 'then do it better']))
# Out:
# [[ 0.13186473  0.32404107 -0.827044   ... -0.37119547 -0.39250168
#   -0.31721845]
#  [ 0.24873517 -0.12334395 -0.38933852 ... -0.44756225 -0.5591354
#   -0.11345169]
#  [ 0.2862736  -0.1858017  -0.30906805 ... -0.2959366  -0.39310506
#    0.07640224]]

# %%
# !python process_data_with_sentence_bert.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 242.65647062040918sec need to to complete
# 1830.2121758249368sec need in total
# 86.75222740772168% done
# 1587.9483823776245sec passed
# 242.4630247425916sec need to to complete
# 1830.2173031931695sec need in total
# 86.76283411115826% done
# 1588.130884885788sec passed
# 242.26712548116384sec need to to complete
# 1830.2039014267sec need in total
# 86.77344081459482% done
# 1588.3095982074738sec passed
# 242.07065301126795sec need to to complete
# 1830.1861537445207sec need in total
# 86.7840475180314% done
# 1588.4832293987274sec passed
# 241.87340987901385sec need to to complete
# 1830.1625344484924sec need in total
# 86.79465422146797% done
# 1588.6663060188293sec passed
# 241.67761050230249sec need to to complete
# 1830.14981994834sec need in total
# 86.80526092490454% done
# 1588.8591046333313sec passed
# 241.48329121817446sec need to to complete
# 1830.1482989980598sec need in total
# 86.81586762834111% done
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/svm_model_y0.joblib /
# !cp /content/drive/MyDrive/svm_model_y1.joblib /
# !cp /content/drive/MyDrive/svm_model_y2.joblib /
# !cp /content/drive/MyDrive/svm_model_y3.joblib /
# !cp /content/drive/MyDrive/svm_model_y4.joblib /

# %%
from predictor import predict
personality = predict("i love to go outside and meet new people")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
# ...

# %%
def map_personality(personality):
    results =[]
    if personality[0] == 1.0:
        results.append("Sociable who's outgoing, energtic and easily talk and make new friends.")
    else: 
        results.append("Reserved who Prefer to unsocialize and doesn't talk or make new friends much.")

    if personality[1] == 1.0:
        results.append("Senstive whose feelings are easily affected and tend to have mood swings or anxiety.")
    else: 
        results.append("Calm who's relaxed and emotionally stable is not affected.")

    if personality[2] == 1.0:
        results.append("Cooperative, Caring and likes to help others you are in need.")
    else: 
        results.append("Competitive who has a little interest in others and their problems.")

    if personality[3] == 1.0:
        results.append("Organized, Efficient and mindful who plan things ahead with its consequences.")
    else: 
        results.append("Careless who don’t like scheduling nor taking care of things.")

    if personality[4] == 1.0:
        results.append("Creative, Curious, adventurous and has eager to learn new experiences and things.")
    else: 
        results.append("Traditional who's not very imaginative and resist new ideas.")
    return results

# %%
print( map_personality(personality) )
# Out:
# ["Sociable who's outgoing, energtic and easily talk and make new friends.", "Calm who's relaxed and emotionally stable is not affected.", 'Cooperative, Caring and likes to help others you are in need.', 'Organized, Efficient and mindful who plan things ahead with its consequences.', 'Creative, Curious, adventurous and has eager to learn new experiences and things.']

# %%
#!cp svm_model_y0.joblib /content/drive/MyDrive
#!cp svm_model_y1.joblib /content/drive/MyDrive
#!cp svm_model_y2.joblib /content/drive/MyDrive
#!cp svm_model_y3.joblib /content/drive/MyDrive
#!cp svm_model_y4.joblib /content/drive/MyDrive
